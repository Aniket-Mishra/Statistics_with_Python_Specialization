# %% [markdown]
# ## Range = max - min

# %% [markdown]
# Example of writing about something
# <br>
# Say a histogram of adult male heights.
# The distribution of adult male heights is roughly bell shaped with a center of about 68 inches, a range of 13 inches (62 ti 75), and no apparent outliers

# %% [markdown]
# #### Bar charts are used for categorical data and histograms are used for quantitative data

# %% [markdown]
# 2 humps in data: bimodal
# <br>
# Long right tail = right skewed therefore the mean is towards the right of the median
# <br>
# Outliers are at the end of the skewed graph. The high end of it. Right skewed -> outliers at the right side

# %% [markdown]
# The distribution of salaries in San Francisco is bimodal and skewed to the right, centered at about $80,000 with most of the data between $40,000 and $120,000, a range of roughly $600,000, and outliers are present on the higher end (more salary).

# %% [markdown]
# In a histogram , talk of 4 main aspects
# <br>
# * Shape
# * Center
# * Spread
# * outlier
# It is a great starting point to decide what we might wanna do with our data

# %% [markdown]
# # numerical summary
#
# IQR = Q3 - Q1 : Measure of spread. <br>
# Std Dev: Avg distance our datapoints fall from the mean. : Measure of spread.
# <br> Std dev: How far away points are from the mean
# <br> Roughly the average distance points are from the mean.

# %% [markdown]
# ### Usually ask why certain values are like that. like if a salary is -600, it might be an input error.

# %% [markdown]
# ### Standard score: Empirical Rule
#
# 1. 68% of all data fall within 1 std dev from the mean
# 2. 95% os all data fall within 2 std dev from the mean
# 3. 99.7% of all data fall within 3 std dev from the mean

# %% [markdown]
# ### Standard score = Z-Score : Negaive: below mean, positive: Above the mean
#
# (value - mean)/std.dev <br>
# (obs - mean) by SD

# %% [markdown]
# ## Box Plots
#
# * Edge of the box: Q1 and Q3.
# * Length of the box: IQR
# * Line in the box: median
# * Min and max are drawn by extending lines out from the box: Whiskers

# %% [markdown]
# ##### Boxplots can hide gaps and clusters in data

# %% [markdown]
# ## How to look at graphs
#
# After looking closely at the interactive graph above, think about these three questions:
#
# • What do you notice?
#
# Share what you are noticing directly from the graph. What may this imply?
#
# • What do you wonder?
#
# What are you curious about that comes from what you notice in the graph?
#
# • What might be going on in this graph?
#
# If you make a claim, tell us what you noticed that supports that your claim is true.
#
# The questions are intended to build on one another, so try to answer them in order. Start with “I notice,” then “I wonder,” and end with “The story this graph is telling is ….”

# %% [markdown]
# # Links:
# https://www.nytimes.com/column/whats-going-on-in-this-graph
# https://www.nytimes.com/interactive/2018/05/03/learning/08WGOITGraphLN.html
# https://www.nytimes.com/2017/10/09/learning/whats-going-on-in-this-graph-oct-10-2017.html
# https://www.nytimes.com/interactive/2018/02/08/learning/13WGOITGraphLN.html
#
# https://www.surveysystem.com/signif.htm
# https://www.dataquest.io/blog/data-science-glossary/

# %% [markdown]
# ## Modern Infographics
# The word infographic comes from a combination of the words “information” and “graphic”. While there are no clear definitions for infographics, generally, these figures should display information with varying levels complexity and sophistication to the viewer in a clear and concise way.
#
# This modern--or not so modern-- technique can take many shapes and forms. Infographics themselves are not a new concept; many basic forms of infographics were first introduced in the 1800s. In fact, many of the charts that you have seen and will see in this course are simple infographics, like pie charts, bar charts, histograms, and scatter plots. Objects such as weather and subway maps are standard ways of displaying and distributing large, complex amounts of information clearly and quickly to users. Well-designed weather maps, for example, are especially helpful in that consistent coloring allows for quick comprehension of information.
# One of the innovations to the infographic that increased its visibility is the development of the USA Snapshots by USA Today in 1982 to add images to simple graphs. The increased illustrations and colors added eye-appeal and extra interest in the information presented. The use of color images in newspapers are often limited to the front and back page of each newspaper, so these graphics were often seen by consumers of the newspaper.
#
#
# With the internet and the massive explosion of social networking sites, Pinterest, and blogs, along with new tools and programs for image editing, infographics have recently exploded in a different way. These infographics exist in almost every format imaginable, whether it be a timeline or an extended visualization of which Disney princess contains the best qualities or a ranking of fruit by tastiness and difficulty of eating. These infographics may be published by reputable sources, like Mott’s Children’s Hospital or generated by unofficial or untrustworthy sources.
#
#
# Due to their rise in number, quantity of authors, and questionable reputability, it is important to assess the quality and correctness of infographics. There are many ways in which infographics can lie or suggest stories that are contained within the data itself.
#
# Some quick tips for assessing how good the data in infographics are:
#
# * Look for the source of the information. Are there competing interests?
# * Check the scale of the data. Many pieces of information can be hidden or exaggerated based on how the scale is generated.
# * While visualizations can be cute, think about how all dimensions of a graph scale. For example, scaling up the height of an object by two will quadruple the two dimensional volume.
#
# So, keep an eye out for infographics in your daily life. During one hour, count how many you see to determine how prevalent they truly are. Assess their correctness based on the underlying data and practice good consumption of information through this format. If you are generating infographics yourself, remember that the clearer you present your information, the clearer and more persuasive your argument will be.
#
# For some of our favorite infographics, check out:
#
# * [How common your birthday is in the US](http://thedailyviz.com/2016/09/17/how-common-is-your-birthday-dailyviz/) <br>
# * [How parents think about organ donation](https://mottpoll.org/infographics/2091)
# <br>
# **And if you're interested in learning more, please review the following resources.**
#
# For general information about infographics, check out:
#
# * [Infographic history](https://www.smithsonianmag.com/history/surprising-history-infographic-180959563/)
# * [The work of Edward Tufte](https://www.edwardtufte.com/tufte/)
# * [How to Be an Educated Consumer on Infographics: David Byrne on the Art-science of Visual Storytelling](https://www.brainpickings.org/2013/10/08/best-american-infographics-david-byrne/)
# <br>
# For more general thoughts on infographics and assessing information, consider looking into:
#
# * [How to lie with Statistics.](https://www.amazon.com/How-Lie-Statistics-Darrell-Huff/dp/0393310728)
# * [Storytelling with Data](http://www.storytellingwithdata.com/)

# %% [markdown]
# ## NumPy
#
# NumPy is the fundamental package for scientific computing with Python. It contains among other things:
#
# * a powerful N-dimensional array object
# * sophisticated (broadcasting) functions
# * tools for integrating C/C++ and Fortran code
# * useful linear algebra, Fourier transform, and random number capabilities
#
# We will focus on the numpy array object.
#
# #### Numpy Array
#
# A numpy array is a grid of values, all of the same type, and is indexed by a tuple of nonnegative integers. The number of dimensions is the rank of the array; the shape of an array is a tuple of integers giving the size of the array along each dimension.

# %% [markdown]
# ## SciPy
#
# Numpy provides a high-performance multidimensional array and basic tools to compute with and manipulate these arrays. SciPy builds on this, and provides a large number of functions that operate on numpy arrays and are useful for different types of scientific and engineering applications.
#
# For this course, we will primariyl be using the **SciPy.Stats** sub-library.
#
# ### SciPy.Stats
#
# The SciPy.Stats module contains a large number of probability distributions as well as a growing library of statistical functions such as:
#
# * Continuous and Discrete Distributions (i.e Normal, Uniform, Binomial, etc.)
#
# * Descriptive Statistcs
#
# * Statistical Tests (i.e T-Test)

# %%
from scipy import stats
import numpy as np

# %%
# Prints normal random variables
print(stats.norm.rvs(size = 10))
# Out:
# [ 1.92714926  0.02735187  0.66604939  0.71240626  2.05708199 -0.88002095
#  -0.03002199 -0.09608239 -0.05075036 -1.20779088]

# %%
from pylab import *

#Creating test data
dx = .01
X = np.arange(-2,2,dx)
Y = exp(-X**2)
# print(Y)
# print(X)

Y /= (dx*Y).sum()
len(Y)

CY = np.cumsum(Y*dx)
# print(CY)

plot(X,Y)
plot(X,CY, 'r--')
show()

# %% [markdown]
# The Probability density function is shown in the blue line graph. <br>
# The Cumelative Density function is showen in the red dotted line.

# %%
print(stats.norm.cdf(np.array([-1.5, -.5, 0, 1, 1.5, 2, 6])))
# Out:
# [0.0668072  0.30853754 0.5        0.84134475 0.9331928  0.97724987
#  1.        ]

# %% [markdown]
# #### Descriptive statistics

# %%
np.random.seed(1234)

x=stats.t.rvs(10,size=1000)

# %% [markdown]
# Seed sets the random seed to a constand value so that we can reproduce the same statistic later.

# %%
print(x.min(), x.max(), x.mean(), x.var())
stats.describe(x)
# Out:
# -3.7081318682862507 5.489762351653657 0.03301501424446721 1.216841589019068
# DescribeResult(nobs=1000, minmax=(-3.7081318682862507, 5.489762351653657), mean=0.03301501424446721, variance=1.2180596486677358, skewness=0.017360162164788, kurtosis=0.9792361694613958)

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

plt.figure(figsize=(10,10))
plt.plot(x, y)
plt.show()

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.figure(figsize=(8,8))
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('sine vs cosine')
plt.legend(['sine', 'cosine'])
plt.show()

# %% [markdown]
# ### Subplots

# %%
plt.figure(figsize = (8,8))

plt.subplot(2, 1, 1)

plt.plot(x, y_sin)
plt.title('Sine')

plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

plt.show()

# %% [markdown]
# ## Seaborn
#
# Seaborn is complimentary to Matplotlib and it specifically targets statistical data visualization. But it goes even further than that: Seaborn extends Matplotlib and makes generating visualizations convenient.
#
# While Matplotlib is a robust solution for various problems, Seaborn utilizes more concise paramesters for ease-of-use.
#
# #### Scatterplots

# %%
import seaborn as sns
import pandas as pd

# %%
url = "Cartwheeldata.csv"

df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-5c0c8283a412> in <module>
#       1 url = "Cartwheeldata.csv"
#       2
# ----> 3 df = pd.read_csv(url)
#
# c:\python 3.8\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# c:\python 3.8\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# c:\python 3.8\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# c:\python 3.8\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# c:\python 3.8\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File Cartwheeldata.csv does not exist: 'Cartwheeldata.csv'

# %%
sns.lmplot(x='Wingspan', y+'CWDistance', data=df)
plt.show()
# Out:
#   File "<ipython-input-39-a55cf13f25a5>", line 1
#     sns.lmplot(x='Wingspan', y+'CWDistance', data=df)
#                              ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# Nice plot tho.

# %%
# Scatterplot arguments
sns.lmplot(x='Wingspan', y='CWDistance', data=df,
           fit_reg=False, # No regression line
           hue='Gender')   # Color by evolution stage

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-5fd6786881a8> in <module>
#       1 # Scatterplot arguments
# ----> 2 sns.lmplot(x='Wingspan', y='CWDistance', data=df,
#       3            fit_reg=False, # No regression line
#       4            hue='Gender')   # Color by evolution stage
#       5
#
# NameError: name 'df' is not defined

# %%
# Construct Cartwheel distance plot
sns.swarmplot(x="Gender", y="CWDistance", data=df)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-374af10f4c2b> in <module>
#       1 # Construct Cartwheel distance plot
# ----> 2 sns.swarmplot(x="Gender", y="CWDistance", data=df)
#       3
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(data=df.loc[:, ["Age", "Height", "Wingspan", "CWDistance", "Score"]])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-36460d36a44e> in <module>
# ----> 1 sns.boxplot(data=df.loc[:, ["Age", "Height", "Wingspan", "CWDistance", "Score"]])
#       2
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
# Male Boxplot
sns.boxplot(data=df.loc[df['Gender'] == 'M', ["Age", "Height", "Wingspan", "CWDistance", "Score"]])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-310820587ab4> in <module>
#       1 # Male Boxplot
# ----> 2 sns.boxplot(data=df.loc[df['Gender'] == 'M', ["Age", "Height", "Wingspan", "CWDistance", "Score"]])
#       3
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
# Female Boxplot
sns.boxplot(data=df.loc[df['Gender'] == 'F', ["Age", "Height", "Wingspan", "CWDistance", "Score"]])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-6333c153a512> in <module>
#       1 # Female Boxplot
# ----> 2 sns.boxplot(data=df.loc[df['Gender'] == 'F', ["Age", "Height", "Wingspan", "CWDistance", "Score"]])
#       3
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
# Male Boxplot
sns.boxplot(data=df.loc[df['Gender'] == 'M', ["Score"]])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-2feaf45ab651> in <module>
#       1 # Male Boxplot
# ----> 2 sns.boxplot(data=df.loc[df['Gender'] == 'M', ["Score"]])
#       3
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
# Female Boxplot
sns.boxplot(data=df.loc[df['Gender'] == 'F', ["Score"]])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-61504bb12e2e> in <module>
#       1 # Female Boxplot
# ----> 2 sns.boxplot(data=df.loc[df['Gender'] == 'F', ["Score"]])
#       3
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
# Distribution Plot (a.k.a. Histogram)
sns.distplot(df.CWDistance)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-40be4cc6da6f> in <module>
#       1 # Distribution Plot (a.k.a. Histogram)
# ----> 2 sns.distplot(df.CWDistance)
#       3
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
# Count Plot (a.k.a. Bar Plot)
sns.countplot(x='Gender', data=df)
 
plt.xticks(rotation=-45)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-14ec2b426ef8> in <module>
#       1 # Count Plot (a.k.a. Bar Plot)
# ----> 2 sns.countplot(x='Gender', data=df)
#       3
#       4 plt.xticks(rotation=-45)
#       5
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Seaborn
#
# ### Tables, Histograms, Boxplots, and Slicing for Statistics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips_data = sns.load_dataset('tips')

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Histograms for the quantitive data

sns.distplot(tips_data['total_bill'], kde = False).set_title('Histogram of total bill')
plt.show()

#Kde = False means the frequency line will not be drawn

# %% [markdown]
# Unimodal, right skewed

# %%
sns.distplot(tips_data['tip'], kde = False).set_title('Histogram of Total Plot')
# Out:
# Text(0.5, 1.0, 'Histogram of Total Plot')

# %% [markdown]
# Unimodal, right skewed

# %%
sns.distplot(tips_data['tip'], kde=False)
sns.distplot(tips_data['total_bill'], kde=False).set_title('histogram of both tip size and total bill')
plt.show()

# %% [markdown]
# If we put a set title on the distplot above the last distplot, itll just take the title of the last distplot
# <br><br>
# Tip size is far smaller than total bill

# %%
sns.boxplot(tips_data['tip']).set_title('boxplot of tips')
plt.show()

# %%
sns.boxplot(tips_data['total_bill']).set_title('boxplot of the total bill')
# Out:
# Text(0.5, 1.0, 'boxplot of the total bill')

# %%
sns.boxplot(tips_data['tip'])
sns.boxplot(tips_data['total_bill'])
plt.show()

# %% [markdown]
# Creating histograms and boxplots plotted by groups

# %%
plt.figure(figsize = (10,10))

sns.boxplot(x=tips_data['tip'], y=tips_data['smoker'])

g = sns.FacetGrid(tips_data, row = "smoker")
g = g.map(plt.hist, 'tip')
plt.show()

# %% [markdown]
# The boxplots are relatively similar. Smokers had the alrgest maximum, they were responsible for the outlier of 10

# %%
sns.boxplot(x=tips_data['tip'], y=tips_data['time'])

# %% [markdown]
# Wee see that dinner is when people give larger tips and the smoker whogave the largest tip did so after dinner. <br>
# we also see that the median of tip size is smaller, ar around 2 quarters during lunch and it is roughly 3 during dinner. <br>
# This maybe because dinner may have a larger total bill in general. But we see that dinner is right skewed as well.

# %%
sns.boxplot(x = tips_data['tip'], y = tips_data['time'])

g = sns.FacetGrid(tips_data, row = 'time')
g = g.map(plt.hist, 'tip')
plt.show()

# %% [markdown]
# We see that both the histograms are right skewed. We also see that there are way more observations for dinner than there are for lunch. <br>
# Typically in this restaurant, people eat a lot more during dinner and are leaving bigger tips.
# <br>
# So, if i was a waiter in this restaurant, i'd take later shifts for bigger tips. (rhymes eh xD)

# %%
#Different days of the week
sns.boxplot(x=tips_data['tip'], y= tips_data['day']).set_title('boxplot of tips on day of the week')
plt.show()

# %% [markdown]
# We see that the best day for tops is saturday and the worst day is Thursday because it has the lowest median. It also seems like sunday is the ebst day on average.

# %%
plt.figure(figsize = (10,10))

sns.boxplot(x=tips_data['tip'], y= tips_data['day']).set_title('boxplot of tips on day of the week')

g = sns.FacetGrid(tips_data, row='day')
g = g.map(plt.hist, 'tip')
plt.figure(figsize = (10,10))


plt.show()

# %% [markdown]
# We see that thursday is a very popular day
# <br>
# friday is very interesting as there aren't many people who visit the restaurant on fridays. We need to investigate this somewhere down the line. <br>
# Saturday is a popular day as well. It is unimodal and right skewed because there are people who give a lot of tips on saturdays (the outliers)
# <br>
# The graph for sunday is interesting. The patterns are not as clear. THe distribution does not have a definite shape, it is partially right skewed. We do not have enough data and we will need to change the size of the bins for future analysis. On an average, Sunday has tips in the range of 4-6 relative to other days.

# %% [markdown]
# ## Check for other combinations like size of party with tip size, the gender and so on.
